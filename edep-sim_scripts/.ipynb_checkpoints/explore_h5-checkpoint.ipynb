# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = h5py.File('test.h5','r')

# %%
print(f.keys())
# Out:
# <KeysViewHDF5 ['segments']>

# %%
f['segments'].dtype
# Out:
# dtype([('eventID', '<u4'), ('z_end', '<f4'), ('trackID', '<u4'), ('tran_diff', '<f4'), ('z_start', '<f4'), ('x_end', '<f4'), ('y_end', '<f4'), ('n_electrons', '<u4'), ('pdgId', '<i4'), ('x_start', '<f4'), ('y_start', '<f4'), ('t_start', '<f4'), ('dx', '<f4'), ('long_diff', '<f4'), ('pixel_plane', '<u4'), ('t_end', '<f4'), ('dEdx', '<f4'), ('dE', '<f4'), ('t', '<f4'), ('y', '<f4'), ('x', '<f4'), ('z', '<f4')])

# %%
#f['segments']['z_start']
#plt.hist(f['segments']['dEdx'])
#f['segments']['pdgId']

# %%
x = (f['segments']['x_start'] + f['segments']['x_end'])/2.0
y = (f['segments']['y_start'] + f['segments']['y_end'])/2.0
z = (f['segments']['z_start'] + f['segments']['z_end'])/2.0

# %%
# plot the edep-sim segments
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
# pixel plane view
plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
